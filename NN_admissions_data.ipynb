# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow	import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import r2_score


# load admissions data
admissions_data = pd.read_csv("https://raw.githubusercontent.com/Mechmay/Neural_Network_Admissions_prediction/master/admissions_data.csv")
#print(admissions_data.head())

#admissions_data.describe()
#print(admissions_data.shape)

# mark predicted values
labels = admissions_data.iloc[:,-1]
#print(labels.describe())

# mark features
features = admissions_data.iloc[:, 1:8]

#split our training and test set
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.25, random_state = 42)

# standardizing our data by scaling it
sc = StandardScaler()
features_train_scale = sc.fit_transform(features_train)
features_test_scale = sc.transform(features_test)

# commented out code for if you want to check out the scaled data

#features_train_scale = pd.DataFrame(features_train_scale, columns = features_train.columns)
#features_test_scale = pd.DataFrame(features_test_scale, columns = features_test.columns)

#print(features_train_scale.describe())
#print(features_test_scale.describe())

# function to design the model
def design_model(feature_data):
	model = Sequential()
	num_features = feature_data.shape[1]
	input = tf.keras.Input(shape=(num_features))
	model.add(input)
	# this model has two hidden layers and two dropout layers
	# relu activation function is used at both hidden layers
	hidden_layer = layers.Dense(16, activation='relu')
	model.add(hidden_layer)
	model.add(layers.Dropout(0.1))
	hidden_layer_2 = layers.Dense(8, activation='relu')
	model.add(hidden_layer_2)
	model.add(layers.Dropout(0.2))
	model.add(layers.Dense(1))

	# using an adam optimizer with a learning rate of 0.005
	# using mean-squared error as our loss function and mean average error as our metric
	opt = keras.optimizers.Adam(learning_rate=0.005)
	model.compile(loss='mse', metrics=['mae'], optimizer=opt)
	return model


# apply the model to the scaled training data
model = design_model(features_train_scale)
#print(model.summary())

# apply early stopping for efficiency
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

# fit the model with 100 epochs and a batch size of 8
# validation split at 0.25
history = model.fit(features_train_scale, labels_train.to_numpy(), epochs=100, batch_size=8, verbose=1, validation_split=0.25, callbacks=[es])

# evaluate the model
val_mse, val_mae = model.evaluate(features_test_scale, labels_test.to_numpy(), verbose = 0)

# view the MAE performance
print("MAE: ", val_mae)

# evaluate r-squared score
y_pred = model.predict(features_test_scale)

print('r2_score: ', r2_score(labels_test,y_pred))

# plot MAE and val_MAE over each epoch
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(history.history['mae'])
ax1.plot(history.history['val_mae'])
ax1.set_title('model mae')
ax1.set_ylabel('MAE')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'validation'], loc='upper left')

# Plot loss and val_loss over each epoch
ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title('model loss')
ax2.set_ylabel('loss')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/100
# 36/36 [==============================] - 1s 7ms/step - loss: 0.5767 - mae: 0.6485 - val_loss: 0.0885 - val_mae: 0.2413
# Epoch 2/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.1134 - mae: 0.2525 - val_loss: 0.0318 - val_mae: 0.1500
# Epoch 3/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0597 - mae: 0.2020 - val_loss: 0.0176 - val_mae: 0.1137
# Epoch 4/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0625 - mae: 0.1925 - val_loss: 0.0164 - val_mae: 0.1082
# Epoch 5/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0473 - mae: 0.1726 - val_loss: 0.0101 - val_mae: 0.0835
# Epoch 6/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0318 - mae: 0.1391 - val_loss: 0.0108 - val_mae: 0.0893
# Epoch 7/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0301 - mae: 0.1299 - val_loss: 0.0091 - val_mae: 0.0791
# Epoch 8/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0216 - mae: 0.1166 - val_loss: 0.0062 - val_mae: 0.0631
# Epoch 9/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0200 - mae: 0.1118 - val_loss: 0.0070 - val_mae: 0.0694
# Epoch 10/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0164 - mae: 0.1002 - val_loss: 0.0060 - val_mae: 0.0638
# Epoch 11/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0140 - mae: 0.0948 - val_loss: 0.0051 - val_mae: 0.0551
# Epoch 12/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0130 - mae: 0.0883 - val_loss: 0.0052 - val_mae: 0.0557
# Epoch 13/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0137 - mae: 0.0890 - val_loss: 0.0050 - val_mae: 0.0560
# Epoch 14/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0116 - mae: 0.0872 - val_loss: 0.0051 - val_mae: 0.0574
# Epoch 15/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0110 - mae: 0.0819 - val_loss: 0.0044 - val_mae: 0.0479
# Epoch 16/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0105 - mae: 0.0834 - val_loss: 0.0049 - val_mae: 0.0543
# Epoch 17/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0091 - mae: 0.0761 - val_loss: 0.0049 - val_mae: 0.0558
# Epoch 18/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0085 - mae: 0.0716 - val_loss: 0.0047 - val_mae: 0.0532
# Epoch 19/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0081 - mae: 0.0680 - val_loss: 0.0046 - val_mae: 0.0517
# Epoch 20/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0085 - mae: 0.0731 - val_loss: 0.0050 - val_mae: 0.0554
# Epoch 21/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0087 - mae: 0.0699 - val_loss: 0.0045 - val_mae: 0.0518
# Epoch 22/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0091 - mae: 0.0751 - val_loss: 0.0042 - val_mae: 0.0497
# Epoch 23/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0090 - mae: 0.0709 - val_loss: 0.0043 - val_mae: 0.0491
# Epoch 24/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0110 - mae: 0.0798 - val_loss: 0.0041 - val_mae: 0.0483
# Epoch 25/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0078 - mae: 0.0684 - val_loss: 0.0042 - val_mae: 0.0477
# Epoch 26/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0080 - mae: 0.0687 - val_loss: 0.0044 - val_mae: 0.0509
# Epoch 27/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0077 - mae: 0.0672 - val_loss: 0.0041 - val_mae: 0.0473
# Epoch 28/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0077 - mae: 0.0673 - val_loss: 0.0046 - val_mae: 0.0539
# Epoch 29/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0081 - mae: 0.0703 - val_loss: 0.0047 - val_mae: 0.0568
# Epoch 30/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0074 - mae: 0.0663 - val_loss: 0.0043 - val_mae: 0.0518
# Epoch 31/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0067 - mae: 0.0638 - val_loss: 0.0040 - val_mae: 0.0478
# Epoch 32/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0092 - mae: 0.0747 - val_loss: 0.0040 - val_mae: 0.0496
# Epoch 33/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0075 - mae: 0.0658 - val_loss: 0.0037 - val_mae: 0.0419
# Epoch 34/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0071 - mae: 0.0651 - val_loss: 0.0048 - val_mae: 0.0562
# Epoch 35/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0072 - mae: 0.0638 - val_loss: 0.0045 - val_mae: 0.0548
# Epoch 36/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0081 - mae: 0.0698 - val_loss: 0.0044 - val_mae: 0.0531
# Epoch 37/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0687 - val_loss: 0.0037 - val_mae: 0.0421
# Epoch 38/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0045 - val_mae: 0.0533
# Epoch 39/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0081 - mae: 0.0651 - val_loss: 0.0041 - val_mae: 0.0481
# Epoch 40/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0067 - mae: 0.0650 - val_loss: 0.0034 - val_mae: 0.0469
# Epoch 41/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0087 - mae: 0.0711 - val_loss: 0.0033 - val_mae: 0.0415
# Epoch 42/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0074 - mae: 0.0658 - val_loss: 0.0036 - val_mae: 0.0486
# Epoch 43/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0094 - mae: 0.0733 - val_loss: 0.0037 - val_mae: 0.0422
# Epoch 44/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0071 - mae: 0.0638 - val_loss: 0.0036 - val_mae: 0.0465
# Epoch 45/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0070 - mae: 0.0624 - val_loss: 0.0031 - val_mae: 0.0408
# Epoch 46/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0594 - val_loss: 0.0038 - val_mae: 0.0477
# Epoch 47/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0063 - mae: 0.0569 - val_loss: 0.0036 - val_mae: 0.0432
# Epoch 48/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0065 - mae: 0.0601 - val_loss: 0.0034 - val_mae: 0.0417
# Epoch 49/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0068 - mae: 0.0640 - val_loss: 0.0035 - val_mae: 0.0442
# Epoch 50/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0581 - val_loss: 0.0031 - val_mae: 0.0431
# Epoch 51/100
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0081 - mae: 0.0682 - val_loss: 0.0032 - val_mae: 0.0414
# Epoch 52/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0063 - mae: 0.0608 - val_loss: 0.0033 - val_mae: 0.0429
# Epoch 53/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0061 - mae: 0.0608 - val_loss: 0.0030 - val_mae: 0.0395
# Epoch 54/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0055 - mae: 0.0578 - val_loss: 0.0035 - val_mae: 0.0400
# Epoch 55/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0081 - mae: 0.0687 - val_loss: 0.0029 - val_mae: 0.0404
# Epoch 56/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0056 - mae: 0.0563 - val_loss: 0.0038 - val_mae: 0.0412
# Epoch 57/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0059 - mae: 0.0582 - val_loss: 0.0028 - val_mae: 0.0388
# Epoch 58/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0063 - mae: 0.0622 - val_loss: 0.0033 - val_mae: 0.0431
# Epoch 59/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0069 - mae: 0.0601 - val_loss: 0.0031 - val_mae: 0.0434
# Epoch 60/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0073 - mae: 0.0650 - val_loss: 0.0033 - val_mae: 0.0445
# Epoch 61/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0055 - mae: 0.0570 - val_loss: 0.0030 - val_mae: 0.0392
# Epoch 62/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0064 - mae: 0.0588 - val_loss: 0.0030 - val_mae: 0.0416
# Epoch 63/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0053 - mae: 0.0594 - val_loss: 0.0036 - val_mae: 0.0488
# Epoch 64/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0056 - mae: 0.0576 - val_loss: 0.0038 - val_mae: 0.0510
# Epoch 65/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0058 - mae: 0.0591 - val_loss: 0.0038 - val_mae: 0.0499
# Epoch 66/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0070 - mae: 0.0646 - val_loss: 0.0033 - val_mae: 0.0404
# Epoch 67/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0058 - mae: 0.0579 - val_loss: 0.0038 - val_mae: 0.0484
# Epoch 68/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0062 - mae: 0.0611 - val_loss: 0.0029 - val_mae: 0.0389
# Epoch 69/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0063 - mae: 0.0613 - val_loss: 0.0033 - val_mae: 0.0471
# Epoch 70/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0054 - mae: 0.0580 - val_loss: 0.0030 - val_mae: 0.0429
# Epoch 71/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0051 - mae: 0.0563 - val_loss: 0.0041 - val_mae: 0.0506
# Epoch 72/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0053 - mae: 0.0557 - val_loss: 0.0038 - val_mae: 0.0471
# Epoch 73/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0074 - mae: 0.0647 - val_loss: 0.0034 - val_mae: 0.0476
# Epoch 74/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0052 - mae: 0.0551 - val_loss: 0.0029 - val_mae: 0.0398
# Epoch 75/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0051 - mae: 0.0547 - val_loss: 0.0035 - val_mae: 0.0445
# Epoch 76/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0060 - mae: 0.0583 - val_loss: 0.0032 - val_mae: 0.0428
# Epoch 77/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0057 - mae: 0.0586 - val_loss: 0.0030 - val_mae: 0.0397
# Epoch 00077: early stopping
# MAE:  0.04429519549012184
# r2_score:  0.7909571279883276
